# %%
# !pip install ultralytics
# !pip install chess
# !pip install pillow
# !pip install mediapipe
# Out:
# Requirement already satisfied: ultralytics in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (8.3.48)
# Requirement already satisfied: numpy>=1.23.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (3.9.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (6.1.0)
# Requirement already satisfied: py-cpuinfo in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from ultralytics) (2.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: setuptools in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: chess in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (1.11.1)
# Requirement already satisfied: pillow in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (11.0.0)
# Requirement already satisfied: mediapipe in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (0.10.18)
# Requirement already satisfied: absl-py in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (0.4.37)
# Requirement already satisfied: jaxlib in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (0.4.36)
# Requirement already satisfied: matplotlib in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (3.9.3)
# Requirement already satisfied: numpy<2 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from jax->mediapipe) (0.5.0)
# Requirement already satisfied: opt_einsum in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from jax->mediapipe) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /Users/betich/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
def create_pgn_csv(video_list, pgn_list, output_csv_path):
    # Prepare the data for the CSV
    rows = [{"row_id": video, "output": pgn} for video, pgn in zip(video_list, pgn_list)]

    # Write to the CSV
    with open(output_csv_path, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=["row_id", "output"])
        writer.writeheader()
        writer.writerows(rows)

    print(f"CSV file has been created at {output_csv_path}.")

# %%
import os
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import datetime

# DRAWING

def show_cv2_image(image, title='image'):
  # plt.figure()
  # plt.title(title)
  # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  # cv2.imwrite(f'{title}_{datetime.datetime.now().strftime("%Y%m%d%H%M%S")}.png', image)
  pass

# OCR
  
def ocr_image(input_image, verbose=False):
    """Detects text in the file."""
    from google.cloud import vision

    client = vision.ImageAnnotatorClient()
    
    content = cv2.imencode('.jpg', input_image)[1].tobytes()

    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    
    if verbose:
        print("Texts:")

        for text in texts:
            print(f'\n"{text.description}"')

            vertices = [
                f"({vertex.x},{vertex.y})" for vertex in text.bounding_poly.vertices
            ]

            print("bounds: {}".format(",".join(vertices)))

    if response.error.message:
        raise Exception(
            "{}\nFor more info on error messages, check: "
            "https://cloud.google.com/apis/design/errors".format(response.error.message)
        )
    
    return texts
  
def detection_to_dict(detection):
    return {
        'description': detection.description,
        'vertices': [
            (vertex.x, vertex.y) for vertex in detection.bounding_poly.vertices
        ]
    }
    
def draw_box(image, a, b, c, d):
  cv2.polylines(image, [np.array([a, b, c, d], np.int32)], True, (0, 255, 0), 2)
  
def show_image_with_ocr(image, title='ocr result'):
  result = ocr_image(image)
  
  if len(image.shape) == 2:
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

  for text in result:
    text_dict = detection_to_dict(text)
    vertices = text_dict['vertices']
    draw_box(image, vertices[0], vertices[1], vertices[2], vertices[3])

  show_cv2_image(image, title)
  
def show_image_with_ocr_labelled(image, title='ocr result'):
  result = ocr_image(image)
  
  if len(image.shape) == 2:
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
  
  for text in result:
    text_dict = detection_to_dict(text)
    vertices = text_dict['vertices']
    draw_box(image, vertices[0], vertices[1], vertices[2], vertices[3])
    cv2.putText(image, text_dict['description'], vertices[0], cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
  
  show_cv2_image(image, title)

# PROCESS IMAGE
  
# Function to compute the intersection of two lines
def compute_intersection(line1, line2):
  rho1, theta1 = line1
  rho2, theta2 = line2

  # Calculate the intersection of two lines
  A = np.array([[np.cos(theta1), np.sin(theta1)], [np.cos(theta2), np.sin(theta2)]])
  b = np.array([rho1, rho2])

  # Solve the linear system to find the intersection point
  intersection = np.linalg.solve(A, b)
  return int(intersection[0]), int(intersection[1])

def draw_white_board_boundaries(image):
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define the range of green color in HSV
    lower_green = np.array([40, 25, 40])  # Lower bound of green in HSV
    upper_green = np.array([100, 200, 200])  # Upper bound of green in HSV

    # Threshold the image to get only the green color
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create a black canvas to draw contours
    contour_image = np.zeros_like(mask)

    # Draw the contours on the black canvas (255 for white contours)
    cv2.drawContours(contour_image, contours, -1, (255), 1)

    # Apply the Canny edge detector on the contour image
    edges = cv2.Canny(contour_image, 50, 150, apertureSize=3)

    # Apply Hough Line Transform to find lines in the edge-detected image
    lines = cv2.HoughLines(edges, 1, np.pi / 180, threshold=100)

    # Separate the lines into vertical and horizontal based on their angle (theta)
    vertical_lines = []
    horizontal_lines = []

    # Find vertical and horizontal lines
    if lines is not None:
        for rho, theta in lines[:, 0]:
            # Identify vertical lines (theta near 0 or 180 degrees)
            if np.abs(theta) < np.pi / 180 * 10 or np.abs(theta - np.pi) < np.pi / 180 * 10:
                vertical_lines.append((rho, theta))
            # Identify horizontal lines (theta near 90 degrees)
            elif np.abs(theta - np.pi / 2) < np.pi / 180 * 10:
                horizontal_lines.append((rho, theta))

    # Create an empty list to store intersection points
    intersection_points = []

    # Find intersection points between vertical and horizontal lines
    for v_line in vertical_lines:
        for h_line in horizontal_lines:
            intersection = compute_intersection(v_line, h_line)
            intersection_points.append(intersection)

    # Create an empty image to draw the intersection points
    intersection_image = np.zeros_like(image)

    # Draw the intersection points on the image (red points)
    for point in intersection_points:
        cv2.circle(intersection_image, point, 10, (0, 0, 255), -1)  # Red circle at intersection points

    # Convert the intersection image to grayscale
    grayscale_image = cv2.cvtColor(intersection_image, cv2.COLOR_BGR2GRAY)

    # Find contours of the red intersection points (non-zero pixels)
    contours, _ = cv2.findContours(grayscale_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create an empty black image to draw the center points
    center_image = np.copy(image)

    # List to store the center points' coordinates
    center_points = []

    # Iterate over each contour and find the centroid (center point)
    for contour in contours:
        # Calculate the moments of the contour
        moments = cv2.moments(contour)
        
        # Calculate the centroid (center) of the contour
        if moments['m00'] != 0:
            cx = int(moments['m10'] / moments['m00'])
            cy = int(moments['m01'] / moments['m00'])
            
            # Draw the center point (blue) on the original image
            cv2.circle(center_image, (cx, cy), 5, (255, 0, 0), -1)  # Blue circle at center
            
            # Store the center coordinates in the list
            center_points.append((cx, cy))
    center_points = sorted(center_points, key=lambda x: sum(x))

    # Step 1: Find the convex hull of the center points
    center_points_np = np.array(center_points, dtype=np.int32)  # Convert to NumPy array
    hull = cv2.convexHull(center_points_np)  # Compute convex hull

    # Step 2: Create a mask for the filled polygon
    mask = np.ones_like(image, dtype=np.uint8) * 255  # Create a white mask with the same dimensions as the image
    cv2.fillPoly(mask, [hull], (0, 0, 0))  # Draw the filled polygon in black on the mask
    
    image[mask == 0] = 255
    result_image = image

    return result_image

def process_image(image):
  processed_image = draw_white_board_boundaries(image)
  
  result = processed_image
  return result

# detect chess board orientation

def bounding_box(left, top, width, height):
  return [(left, top), (left + width, top), (left + width, top + height), (left, top + height)]

def draw_bounding_box(image, box, color=(0, 255, 0)):
  cv2.polylines(image, [np.array(box)], isClosed=True, color=color, thickness=2)
  return image

def get_board_orientation(bound_8, bound_h):
  # compute the center of the two bounding boxes
  center_8 = np.mean(np.array(bound_8), axis=0)
  center_h = np.mean(np.array(bound_h), axis=0)
  
  # check the relative position of the two centers
  if center_8[0] < center_h[0] and center_8[1] < center_h[1]:
    return 'UPRIGHT'
  elif center_8[0] > center_h[0] and center_8[1] > center_h[1]:
    return 'UPSIDE_DOWN'
  elif center_8[0] < center_h[0] and center_8[1] > center_h[1]:
    return 'ROTATED_RIGHT'
  elif center_8[0] > center_h[0] and center_8[1] < center_h[1]:
    return 'ROTATED_LEFT'
  

def detect_chessboard_orientation(image):
  data = ocr_image(image)
  
  bounds_8 = [] # sample: [(x1, y1), (x2, y2), (x3, y3), (x4, y4)]
  bounds_h = [] # sample: [(x1, y1), (x2, y2), (x3, y3), (x4, y4)]
  
  for detection in data:
    data_dict = detection_to_dict(detection)
    if data_dict['description'] == '8':
      # store the bounding box of the 8
      bounds_8.append(data_dict['vertices'])
    elif data_dict['description'] == 'h':
      bounds_h.append(data_dict['vertices'])
  
  # find the closest pair of 8 and h
  closest = None
  
  for bound_8 in bounds_8:
    for bound_h in bounds_h:
      distance = np.linalg.norm(np.array(bound_8) - np.array(bound_h))
      
      if closest is None or distance < closest[0]:
        closest = (distance, bound_8, bound_h)
        
  print(f'Closest pair: {closest}')
  
  if closest is None:
    return False, closest
  
  # compute the center of the two bounding boxes
  center_8 = np.mean(np.array(closest[1]), axis=0)
  center_h = np.mean(np.array(closest[2]), axis=0)
  
  # draw the line between the two points
  cv2.line(image, tuple(center_8.astype(int)), tuple(center_h.astype(int)), (255, 0, 0), 2)
  
  # draw the bounding boxes
  image = draw_bounding_box(image, bound_8, (0, 255, 0))
  image = draw_bounding_box(image, bound_h, (0, 0, 255))
  
  show_cv2_image(image, "detected image")
    
  return get_board_orientation(closest[1], closest[2]), closest

def get_k(image):  
  images = [image]
  
  for i in range(3):
    images.append(cv2.rotate(images[-1], cv2.ROTATE_90_CLOCKWISE))
    
  k = 0
  for i in range(4):
    result = detect_chessboard_orientation(process_image(images[i]))
    
    if result[0] and result[1]:
      bound_8 = result[1][1][0]
      bound_h = result[1][1][1]
      
      # bound_8 and bound_h are in the bottom-left window of the image
      h, w = images[i].shape[:2]
      
      if bound_8[0] < w / 2 and bound_8[1] > h / 2 and bound_h[0] < w / 2 and bound_h[1] > h / 2:
        k = i
        break
        
  return k

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from PIL import Image
import chess
import time
import chess.pgn
import mediapipe as mp
from statistics import mode

# Define a mapping of YOLO labels to chess piece names
def label_to_piece_name(label):
    piece_map = {
        1: "bB",  # black-bishop
        2: "bK",  # black-king
        3: "bN",  # black-knight
        4: "bP",  # black-pawn
        5: "bQ",  # black-queen
        6: "bR",  # black-rook
        7: "wB",  # white-bishop
        8: "wK",  # white-king
        9: "wN",  # white-knight
        10: "wP", # white-pawn
        11: "wQ", # white-queen
        12: "wR"  # white-rook
    }
    return piece_map.get(label, "?")

# Function to find intersection points of the grid lines
def find_grid(image, k=0):
    # image = cv2.imread(image_path)

    # Convert the image to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    
    for i in range(k):
        hsv = cv2.rotate(hsv, cv2.ROTATE_90_CLOCKWISE)
    
    # Define the range of green color in HSV (assuming green grid lines)
    lower_green = np.array([40, 25, 40])   # Lower bound of green in HSV
    upper_green = np.array([100, 200, 200]) # Upper bound of green in HSV

    # Threshold the image to get only the green color
    mask = cv2.inRange(hsv, lower_green, upper_green)

    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create a black canvas to draw contours
    contour_image = np.zeros_like(mask)

    # Draw the contours on the black canvas (255 for white contours)
    cv2.drawContours(contour_image, contours, -1, (255), 1)

    # Apply Canny edge detector
    edges = cv2.Canny(contour_image, 50, 150, apertureSize=3)

    # Apply Hough Line Transform to find lines in the edge-detected image
    lines = cv2.HoughLines(edges, 1, np.pi / 180, threshold=100)

    # Separate the lines into vertical and horizontal based on their angle
    vertical_lines = []
    horizontal_lines = []

    # Find vertical and horizontal lines
    if lines is not None:
        for rho, theta in lines[:, 0]:
            # Identify vertical lines (theta near 0 or 180 degrees)
            if np.abs(theta) < np.pi / 180 * 10 or np.abs(theta - np.pi) < np.pi / 180 * 10:
                vertical_lines.append((rho, theta))
            # Identify horizontal lines (theta near 90 degrees)
            elif np.abs(theta - np.pi / 2) < np.pi / 180 * 10:
                horizontal_lines.append((rho, theta))

    # Create an empty list to store intersection points
    intersection_points = []

    # Function to compute the intersection of two lines
    def compute_intersection(line1, line2):
        rho1, theta1 = line1
        rho2, theta2 = line2

        A = np.array([[np.cos(theta1), np.sin(theta1)], [np.cos(theta2), np.sin(theta2)]])
        b = np.array([rho1, rho2])

        # Solve the linear system to find the intersection point
        intersection = np.linalg.solve(A, b)
        return int(intersection[0]), int(intersection[1])

    # Find intersection points between vertical and horizontal lines
    for v_line in vertical_lines:
        for h_line in horizontal_lines:
            intersection = compute_intersection(v_line, h_line)
            intersection_points.append(intersection)

    return intersection_points

# Function to map detected chess pieces to the board using intersection points

def map_yolo_results_to_chessboard(results, chessboard_corners):
    """
    Maps YOLO detection results to a chessboard grid.

    Args:
    - results: YOLO detection results containing labels and bounding boxes.
    - chessboard_corners: List of tuples [(x1, y1), (x2, y2), ..., (x4, y4)]
                          representing the corners of the chessboard
                          (top-left, top-right, bottom-left, bottom-right).

    Returns:
    - A formatted string representation of the chessboard with mapped pieces.
    """
    # Extract the chessboard corners
    top_left, top_right, bottom_left, bottom_right = chessboard_corners

    # Calculate the width and height of each cell
    cell_width = (top_right[0] - top_left[0]) / 8
    cell_height = (bottom_left[1] - top_left[1]) / 8

    # Initialize an empty 8x8 chessboard
    board = [['' for _ in range(8)] for _ in range(8)]

    # Process YOLO results
    for r in results:
        boxes = r.boxes.xywh.numpy()  # Bounding boxes in (x_center, y_center, width, height)
        labels = r.boxes.cls.numpy()  # Class indices
        
        for box, label in zip(boxes, labels):
            x_center, y_center, _, _ = box
            piece_name = label_to_piece_name(int(label))

            # Determine the row and column based on the center point
            col = int((x_center - top_left[0]) / cell_width)
            row = int((y_center - top_left[1]) / cell_height)

            # Ensure row and col are within bounds
            if 0 <= row < 8 and 0 <= col < 8:
                board[row][col] = piece_name

    # Format the board for display
    formatted_board = '\n'.join([' '.join([cell if cell else '--' for cell in row]) for row in board])
    return formatted_board

def convert_to_valid_fen(board_string):
    # Mapping of custom pieces to FEN standard pieces
    piece_mapping = {
        "wP": "P", "wR": "R", "wN": "N", "wB": "B", "wQ": "Q", "wK": "K",
        "bP": "p", "bR": "r", "bN": "n", "bB": "b", "bQ": "q", "bK": "k",
        "--": "1"  # Empty squares
    }
    
    # Split the input string into rows
    rows = board_string.strip().split("\n")
    
    fen_rows = []
    for row in rows:
        squares = row.split()  # Split the row into individual squares
        fen_row = ""
        for square in squares:
            fen_row += piece_mapping.get(square, square)  # Replace with mapped value
        
        # Compress consecutive digits (empty spaces) into single numbers
        compressed_row = ""
        empty_count = 0
        for char in fen_row:
            if char.isdigit():  # Count empty squares
                empty_count += int(char)
            else:
                if empty_count > 0:
                    compressed_row += str(empty_count)
                    empty_count = 0
                compressed_row += char
        if empty_count > 0:
            compressed_row += str(empty_count)  # Add remaining empty squares
        fen_rows.append(compressed_row)
    
    # Combine rows with "/" and add default metadata
    fen_board = "/".join(fen_rows)
    fen_metadata = " w - - 0 1"  # White to move, no castling, no en passant
    return fen_board + fen_metadata

def rotate_fen(fen):
    # Split the FEN into board state and other details
    board, *rest = fen.split(' ')
    
    # Split the board into rows
    rows = board.split('/')
    
    # Rotate each row (reverse the pieces) and then reverse the row order
    rotated_rows = [''.join(reversed(row)) for row in reversed(rows)]
    
    # Recombine the rows into the rotated FEN
    rotated_board = '/'.join(rotated_rows)
    
    # Combine the rotated board with the rest of the FEN details
    return ' '.join([rotated_board] + rest)

def convert_to_san(moves):
    san_moves = []
    move_number = 1

    for i in range(0, len(moves), 2):
        if i + 1 < len(moves):
            # Pair moves for each turn
            san_moves.append(f"{move_number}. {moves[i]} {moves[i+1]}")
        else:
            # If there's an odd move at the end, only record that
            san_moves.append(f"{move_number}. {moves[i]}")
        move_number += 1

    return " ".join(san_moves)


def get_chessboard_corners(image, k=0):
    coor = find_grid(image, k)
    coor = sorted(coor, key=lambda x: sum(x))
    min = coor[0]
    max = coor[-1]

    chessboard_corners = [(min[0], min[1]), (max[0], min[1]), (min[0], max[1]), (max[0], max[1])]

    return chessboard_corners

def board_list_to_list(board_list):
    output = [[[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]],
              [[],[],[],[],[],[],[],[]]]


    for board in board_list:
        board_splitR = board.split("\n")
        for r,board_row in enumerate(board_splitR):
            board_pos = board_row.split(" ")
            for c,piece in enumerate(board_pos):
                output[r][c].append(piece)

    for r,row in enumerate(output):
        for c,col in enumerate(row):
            output[r][c] = mode(col)

    return output

def board_to_pgn(prev_b, curr_b):
    board_pos_coor = [['a8', 'b8', 'c8', 'd8', 'e8', 'f8','g8','h8'],
                    ['a7', 'b7', 'c7', 'd7', 'e7', 'f7','g7','h7'],
                    ['a6', 'b6', 'c6', 'd6', 'e6', 'f6','g6','h6'],
                    ['a5', 'b5', 'c5', 'd5', 'e5', 'f5','g5','h5'],
                    ['a4', 'b4', 'c4', 'd4', 'e4', 'f4','g4','h4'],
                    ['a3', 'b3', 'c3', 'd3', 'e3', 'f3','g3','h3'],
                    ['a2', 'b2', 'c2', 'd2', 'e2', 'f2','g2','h2'],
                    ['a1', 'b1', 'c1', 'd1', 'e1', 'f1','g1','h1']]

    # Find the coordinates of the changed piece
    moved_from = None
    moved_to = None
    
    for row in range(8):
        for col in range(8):
            if prev_b[row][col] != curr_b[row][col]:
                if curr_b[row][col] == '.':
                    # The piece moved from this square
                    moved_from = (row, col)
                else:
                    # The piece moved to this square
                    moved_to = (row, col)
    
    if moved_from is None or moved_to is None:
        return "No valid move found", False  # In case of invalid input

    # Convert coordinates to chess notation
    from_square = board_pos_coor[moved_from[0]][moved_from[1]]
    to_square = board_pos_coor[moved_to[0]][moved_to[1]]

    moved_piece = prev_b[moved_from[0]][moved_from[1]]
    if moved_piece.islower():  # black move
        if prev_b[moved_to[0]][moved_to[1]] != '.': # black capture
            if moved_piece == 'p':
                pgn = f"{board_pos_coor[moved_from[0]][moved_from[1]][0]}x{to_square}"  # black pawn capture
            else:
                pgn = f"{moved_piece.upper()}x{to_square}" #black non pawn capture
        else: # not capture
            if moved_piece == 'p':
                moved_piece = ""
            else:
                moved_piece = moved_piece.upper()
            pgn = f"{moved_piece}{to_square}"  # Regular pawn move
    else:  # white
        if prev_b[moved_to[0]][moved_to[1]] != '.': # capture
            if moved_piece == 'P':
                pgn = f"{board_pos_coor[moved_from[0]][moved_from[1]][0]}x{to_square}"  # capture
            else:
                pgn = f"{moved_piece}x{to_square}"
        else: # not capture
            if moved_piece == 'P':
                pgn = f"{to_square}"  # Regular piece move
            else:
                pgn = f"{moved_piece}{to_square}"  # Regular pawn move
   
    is_white = prev_b[moved_from[0]][moved_from[1]].isupper()

    return pgn, is_white



def gen_pgn(vid_path, model):
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
    # mp_drawing = mp.solutions.drawing_utils

    cap = cv2.VideoCapture(vid_path)
    
    # Parameters for frame processing
    frame_count = 0
    frame_interval = int(float(cap.get(cv2.CAP_PROP_FPS)) * 0.5)  # Process frame every 1 second
    # previous_board = None  # Track the previous board state
    # previous_hand_present = False  # Track if a hand was detected in the previous frame
    
    # list of board list; appends the board_lists
    board_list_list = []

    # board list iterate every time hand is present
    board_list = []
    
    # get one frame
    print('getting k from gen_pgn')
    k = get_k(cap.read()[1])

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            if len(board_list) != 0:
                board_list_list.append(board_list)
                board_list = []
            break  # End of video

        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Perform hand detection
        hand_results = hands.process(rgb_frame)
        not_hand_present = hand_results.multi_hand_landmarks == None

        # Crop the frame
        frame = frame[425:1495, :]
        
        for i in range(k):
          frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
        
        # Process frame every frame_interval
        if frame_count % frame_interval == 0:
            if not_hand_present:
                results = model(frame, conf=0.3)
                chessboard_corners = get_chessboard_corners(frame, k)

                formatted_board = map_yolo_results_to_chessboard(results, chessboard_corners)

                fen = convert_to_valid_fen(formatted_board)
                fen = rotate_fen(fen)

                current_board = chess.Board(fen)
                #print('board')
                board_list.append(str(current_board)[1:-1])
            elif not not_hand_present or not ret:
                #print('hand')
                if len(board_list) != 0:
                    board_list_list.append(board_list)
                board_list = []
        
        # Increment frame counter
        frame_count += 1

    #san_notation = convert_to_san(['..'] + san_move)
   # print(san_notation)
    
    # cap.release()
    # cv2.destroyAllWindows()
    # print(board_list_list)
    # print(len(board_list_list))
    # print(board_list_list[0])
    # print(board_list_list[1])
    # print(board_list_list[2])

    for i,b_list in enumerate(board_list_list):
        print(b_list)
        new_board_list = board_list_to_list(b_list)
        board_list_list[i] = new_board_list
        print(str(new_board_list)+"\n\n")

    pgn_index = 1
    white_move = ".."
    black_move = ".."

    pgn_all = [""]

    for i in range(len(board_list_list) - 1):
        
        p_board = board_list_list[i]
        c_board = board_list_list[i + 1]
        pgn, is_white = board_to_pgn(prev_b=p_board, curr_b=c_board)

        if is_white:
            white_move = pgn
        else:
            black_move = pgn
        
        pgn_row = f"{pgn_index}. {white_move} {black_move} "

        if is_white or (not is_white and black_move != ".."):
            if len(pgn_all) < pgn_index:
                pgn_all.append(pgn_row)
            else:
                pgn_all[pgn_index - 1] = pgn_row

        if black_move != "..":
            white_move = ".."
            black_move = ".."
            pgn_index += 1


    out_str = ""

    for r in pgn_all:
        out_str += r
        
    if out_str == "":
        return '1. '
        
    return out_str

# # Initialize Mediapipe Hands
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
# mp_drawing = mp.solutions.drawing_utils

# 1. .. move 2. move ..

# Load the YOLO model
model = YOLO("best2.pt")  # Replace with the path to your trained YOLO model
# image_path = "detection/test2.jpg"

# image = cv2.imread(image_path)
video_path_2m = "kaggle/input/2_move_student.mp4"  # Replace with the path to your video
video_path_4m = "kaggle/input/4_Move_studet.mp4"  # Replace with the path to your video
video_path_6m = "kaggle/input/6_Move_student.mp4"  # Replace with the path to your video
video_path_8m = "kaggle/input/8_Move_student.mp4"  # Replace with the path to your video
video_path_2mr = "kaggle/input/2_Move_rotate_student.mp4"



video_path_list = [video_path_2mr, video_path_2m, video_path_4m, video_path_6m, video_path_8m]

output_path = "kaggle/output/output_video.avi"  # Optional: Specify a path to save the output video

# for vidp in vidp_list:
# for vidp in video_path_list:
#     gen_pgn(vidp, model)
print(gen_pgn(video_path_4m, model))

# Release resources

#R . B . Q . . R
#P P K . . P . P
#. . . . . N . .
#q . . P . . P .
#. . . p P . . n
#. . . . p . . .
#. p . . b p p p
#R n b k . . . .

#R . B . Q . . R
#P . K . . P . P
#. P . . . N . .
#q . . P . . P .
#. . . p P . . n
#. . . . p . . .
#. p . . b p p p
#R n b k . . . .
# Out:
# I0000 00:00:1733859472.639562  787626 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 83.1), renderer: Apple M1
# W0000 00:00:1733859472.660690 1014226 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733859472.667263 1014226 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# getting k from gen_pgn
# Closest pair: (219.98181743044128, [(39, 1317), (52, 1318), (51, 1335), (38, 1334)], [(115, 1393), (132, 1393), (132, 1413), (115, 1413)])
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 248.8ms
# Speed: 3.5ms preprocess, 248.8ms inference, 10.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.8ms
# Speed: 1.1ms preprocess, 139.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.7ms
# Speed: 1.0ms preprocess, 136.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 133.9ms
# Speed: 1.1ms preprocess, 133.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 131.0ms
# Speed: 1.3ms preprocess, 131.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.0ms
# Speed: 1.2ms preprocess, 136.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 134.4ms
# Speed: 1.1ms preprocess, 134.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 158.8ms
# Speed: 1.3ms preprocess, 158.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.3ms
# Speed: 1.3ms preprocess, 136.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.9ms
# Speed: 1.0ms preprocess, 136.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 142.4ms
# Speed: 1.6ms preprocess, 142.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 133.0ms
# Speed: 1.1ms preprocess, 133.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 132.0ms
# Speed: 1.0ms preprocess, 132.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.7ms
# Speed: 1.8ms preprocess, 136.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 185.7ms
# Speed: 2.1ms preprocess, 185.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 169.2ms
# Speed: 1.3ms preprocess, 169.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 188.5ms
# Speed: 2.2ms preprocess, 188.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.6ms
# Speed: 1.0ms preprocess, 139.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.5ms
# Speed: 1.2ms preprocess, 136.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 126.2ms
# Speed: 1.1ms preprocess, 126.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.6ms
# Speed: 1.6ms preprocess, 141.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 131.7ms
# Speed: 1.2ms preprocess, 131.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 198.3ms
# Speed: 2.5ms preprocess, 198.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.1ms
# Speed: 1.1ms preprocess, 141.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 153.2ms
# Speed: 1.5ms preprocess, 153.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.5ms
# Speed: 1.7ms preprocess, 139.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 208.4ms
# Speed: 2.1ms preprocess, 208.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 319.9ms
# Speed: 9.6ms preprocess, 319.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 225.5ms
# Speed: 3.4ms preprocess, 225.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 208.8ms
# Speed: 1.7ms preprocess, 208.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 254.9ms
# Speed: 1.2ms preprocess, 254.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 241.1ms
# Speed: 1.4ms preprocess, 241.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 219.9ms
# Speed: 1.5ms preprocess, 219.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 192.2ms
# Speed: 2.5ms preprocess, 192.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 329.6ms
# Speed: 2.3ms preprocess, 329.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 194.7ms
# Speed: 3.4ms preprocess, 194.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 164.8ms
# Speed: 1.5ms preprocess, 164.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 167.1ms
# Speed: 1.0ms preprocess, 167.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 147.4ms
# Speed: 1.4ms preprocess, 147.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 168.9ms
# Speed: 2.1ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 179.7ms
# Speed: 1.8ms preprocess, 179.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 170.3ms
# Speed: 1.2ms preprocess, 170.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.3ms
# Speed: 1.4ms preprocess, 136.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.6ms
# Speed: 1.4ms preprocess, 139.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 149.9ms
# Speed: 1.3ms preprocess, 149.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 3 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 135.4ms
# Speed: 1.2ms preprocess, 135.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 172.2ms
# Speed: 1.1ms preprocess, 172.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.9ms
# Speed: 1.3ms preprocess, 139.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 135.8ms
# Speed: 1.5ms preprocess, 135.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 128.0ms
# Speed: 1.5ms preprocess, 128.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 161.6ms
# Speed: 1.0ms preprocess, 161.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 140.9ms
# Speed: 1.1ms preprocess, 140.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 133.2ms
# Speed: 1.2ms preprocess, 133.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 165.7ms
# Speed: 2.3ms preprocess, 165.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.4ms
# Speed: 1.6ms preprocess, 141.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 134.6ms
# Speed: 1.2ms preprocess, 134.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 137.9ms
# Speed: 1.3ms preprocess, 137.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 210.8ms
# Speed: 2.4ms preprocess, 210.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 151.9ms
# Speed: 1.5ms preprocess, 151.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 169.2ms
# Speed: 1.4ms preprocess, 169.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 169.1ms
# Speed: 2.3ms preprocess, 169.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 166.6ms
# Speed: 2.3ms preprocess, 166.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 173.3ms
# Speed: 1.2ms preprocess, 173.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 157.8ms
# Speed: 1.5ms preprocess, 157.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 130.1ms
# Speed: 1.1ms preprocess, 130.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 146.2ms
# Speed: 1.3ms preprocess, 146.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 141.0ms
# Speed: 1.1ms preprocess, 141.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 153.8ms
# Speed: 1.3ms preprocess, 153.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 133.9ms
# Speed: 1.1ms preprocess, 133.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 179.9ms
# Speed: 1.5ms preprocess, 179.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 140.7ms
# Speed: 1.3ms preprocess, 140.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 132.3ms
# Speed: 1.3ms preprocess, 132.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 139.1ms
# Speed: 1.3ms preprocess, 139.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 222.7ms
# Speed: 1.6ms preprocess, 222.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 140.4ms
# Speed: 1.3ms preprocess, 140.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 193.0ms
# Speed: 1.6ms preprocess, 193.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 206.3ms
# Speed: 2.2ms preprocess, 206.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 142.2ms
# Speed: 1.5ms preprocess, 142.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 174.3ms
# Speed: 1.1ms preprocess, 174.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 129.8ms
# Speed: 1.2ms preprocess, 129.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 127.9ms
# Speed: 1.3ms preprocess, 127.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 128.6ms
# Speed: 1.0ms preprocess, 128.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 128.2ms
# Speed: 1.0ms preprocess, 128.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 159.2ms
# Speed: 1.2ms preprocess, 159.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 147.9ms
# Speed: 1.2ms preprocess, 147.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 144.1ms
# Speed: 1.7ms preprocess, 144.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 152.1ms
# Speed: 2.1ms preprocess, 152.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 147.7ms
# Speed: 1.4ms preprocess, 147.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 192.5ms
# Speed: 2.2ms preprocess, 192.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 201.7ms
# Speed: 1.2ms preprocess, 201.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 205.4ms
# Speed: 2.0ms preprocess, 205.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 147.3ms
# Speed: 1.2ms preprocess, 147.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.0ms
# Speed: 1.1ms preprocess, 139.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 174.8ms
# Speed: 1.2ms preprocess, 174.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 176.8ms
# Speed: 1.6ms preprocess, 176.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 166.5ms
# Speed: 1.7ms preprocess, 166.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 169.7ms
# Speed: 1.8ms preprocess, 169.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 164.2ms
# Speed: 1.7ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 166.7ms
# Speed: 1.3ms preprocess, 166.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 163.4ms
# Speed: 1.6ms preprocess, 163.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 167.6ms
# Speed: 1.1ms preprocess, 167.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 169.2ms
# Speed: 1.4ms preprocess, 169.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 168.5ms
# Speed: 1.5ms preprocess, 168.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 182.8ms
# Speed: 1.4ms preprocess, 182.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 151.5ms
# Speed: 1.2ms preprocess, 151.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 135.4ms
# Speed: 1.3ms preprocess, 135.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 184.2ms
# Speed: 1.0ms preprocess, 184.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 132.8ms
# Speed: 1.6ms preprocess, 132.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 128.4ms
# Speed: 1.4ms preprocess, 128.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 130.2ms
# Speed: 1.2ms preprocess, 130.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 127.6ms
# Speed: 1.1ms preprocess, 127.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 125.3ms
# Speed: 1.4ms preprocess, 125.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.9ms
# Speed: 1.3ms preprocess, 136.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 132.0ms
# Speed: 1.3ms preprocess, 132.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 181.0ms
# Speed: 1.2ms preprocess, 181.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 140.3ms
# Speed: 1.1ms preprocess, 140.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 157.1ms
# Speed: 1.3ms preprocess, 157.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 133.0ms
# Speed: 1.2ms preprocess, 133.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 139.6ms
# Speed: 1.8ms preprocess, 139.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 137.7ms
# Speed: 1.2ms preprocess, 137.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 282.4ms
# Speed: 1.8ms preprocess, 282.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 186.7ms
# Speed: 1.2ms preprocess, 186.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 145.0ms
# Speed: 0.9ms preprocess, 145.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.5ms
# Speed: 1.6ms preprocess, 141.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 140.7ms
# Speed: 1.3ms preprocess, 140.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 162.2ms
# Speed: 1.2ms preprocess, 162.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 137.8ms
# Speed: 1.3ms preprocess, 137.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 143.4ms
# Speed: 1.4ms preprocess, 143.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.9ms
# Speed: 1.6ms preprocess, 141.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 131.6ms
# Speed: 1.6ms preprocess, 131.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 140.3ms
# Speed: 1.1ms preprocess, 140.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 134.3ms
# Speed: 1.2ms preprocess, 134.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 175.6ms
# Speed: 1.1ms preprocess, 175.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.7ms
# Speed: 1.2ms preprocess, 141.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.6ms
# Speed: 1.2ms preprocess, 136.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 152.1ms
# Speed: 1.3ms preprocess, 152.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 133.4ms
# Speed: 1.3ms preprocess, 133.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 146.2ms
# Speed: 1.4ms preprocess, 146.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 135.7ms
# Speed: 1.1ms preprocess, 135.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 144.5ms
# Speed: 1.5ms preprocess, 144.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 136.4ms
# Speed: 1.3ms preprocess, 136.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 135.8ms
# Speed: 1.2ms preprocess, 135.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 152.2ms
# Speed: 1.0ms preprocess, 152.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 157.5ms
# Speed: 1.1ms preprocess, 157.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 135.7ms
# Speed: 1.1ms preprocess, 135.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 3 white-rooks, 139.0ms
# Speed: 1.1ms preprocess, 139.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 184.8ms
# Speed: 1.2ms preprocess, 184.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 141.1ms
# Speed: 1.3ms preprocess, 141.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 164.3ms
# Speed: 2.0ms preprocess, 164.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 2 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 165.7ms
# Speed: 1.4ms preprocess, 165.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 3 black-queens, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 149.7ms
# Speed: 1.2ms preprocess, 149.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 161.3ms
# Speed: 1.5ms preprocess, 161.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 155.2ms
# Speed: 1.5ms preprocess, 155.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 7 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 145.5ms
# Speed: 1.1ms preprocess, 145.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# ...
# [['', '.', '.', 'q', 'k', 'b', 'n', 'r'], ['p', 'p', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', 'p', '.', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', 'N'], ['.', '.', 'N', '.', '.', '.', 'B', '.'], ['P', '.', 'P', '.', '.', 'P', 'P', 'P'], ['R', '.', '.', 'Q', 'K', 'B', '.', '']]
#
#
# [' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P p . N\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . . .\nn .  ...
# [['', '.', '.', 'q', 'k', 'b', 'n', 'r'], ['p', 'p', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', '.', '.', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', 'p', '.', 'N'], ['.', '.', 'N', '.', '.', '.', 'B', '.'], ['P', '.', 'P', '.', '.', 'P', 'P', 'P'], ['R', '.', '.', 'Q', 'K', 'B', '.', '']]
#
#
# [' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\n. P P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P p . .\n. . N . . . B .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn .  ...
# [['', '.', '.', 'q', 'k', 'b', 'n', 'r'], ['p', 'p', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', '.', 'N', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', 'p', '.', '.'], ['.', '.', 'N', '.', '.', '.', 'B', '.'], ['P', '.', 'P', '.', '.', 'P', 'P', 'P'], ['R', '.', '.', 'Q', 'K', 'B', '.', '']]
#
#
# [' . . q k q n r\n. . . q . . p .\n. . . . . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . . . . . r\np p p . . . . .\n. . . n . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . . . . r r\np p p . . . . .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ']
# [['', '.', '.', '.', '.', '.', 'n', 'r'], ['p', 'p', 'p', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', 'N', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', '.'], ['.', '.', 'N', '.', '.', '.', 'p', '.'], ['P', '.', 'P', '.', '.', 'P', 'P', 'P'], ['R', '.', '.', 'Q', 'K', 'B', '.', '']]
#
#
# [' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\n. P P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np b p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . R . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K K . ', ' . . k k b n r\np p p b . . p .\n. . . p . . N .\nq . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n r\nq p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K Q . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n r\np p p b . . p .\n. . . p . . N .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ']
# [['', '.', '.', 'q', 'k', 'b', 'n', 'r'], ['p', 'p', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', '.', 'N', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', '.'], ['.', '.', 'N', '.', '.', '.', 'p', '.'], ['P', '.', 'P', '.', '.', 'P', 'P', 'P'], ['R', '.', '.', 'Q', 'K', 'B', '.', '']]
#
#
# [' . . q k b n R\np p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K Q . ', ' . . q k b n N\np p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\nq p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\n. P P . . P P P\nR . . Q K B . ', ' . . q k b n R\np p p b . . p .\n. . . p . . . .\nq . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\nq p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\nq p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ', ' . . q k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nP . P . . P P P\nR . . Q K B . ', ' . . q k b n R\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . p .\nR . P . . P P P\nR . . Q K B . ']
# [['', '.', '.', 'q', 'k', 'b', 'n', 'N'], ['p', 'p', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', '.', '.', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', '.'], ['.', '.', 'N', '.', '.', '.', 'p', '.'], ['P', '.', 'P', '.', '.', 'P', 'P', 'P'], ['R', '.', '.', 'Q', 'K', 'B', '.', '']]
#
#
# 1. .. f4 2. Ng6 fxg3 3. .. No valid move found 4. Nxh8 ..

# %%
pgn = []
for path in video_path_list:
    pgn.append(gen_pgn(path, model))

print(pgn)
# Out:
# getting k from gen_pgn
# I0000 00:00:1733859604.150726  787626 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 83.1), renderer: Apple M1
# W0000 00:00:1733859604.159823 1016317 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733859604.168831 1016317 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Closest pair: (217.9632996630396, [(908, 1460), (908, 1445), (922, 1445), (922, 1460)], [(980, 1383), (980, 1365), (1001, 1365), (1001, 1383)])
# Closest pair: (215.67104580819372, [(459, 905), (475, 905), (475, 922), (459, 922)], [(535, 981), (551, 981), (551, 999), (535, 999)])
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 183.2ms
# Speed: 2.9ms preprocess, 183.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 138.3ms
# Speed: 1.6ms preprocess, 138.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 140.3ms
# Speed: 1.1ms preprocess, 140.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 173.4ms
# Speed: 1.3ms preprocess, 173.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 156.6ms
# Speed: 0.9ms preprocess, 156.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 135.0ms
# Speed: 1.8ms preprocess, 135.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 134.9ms
# Speed: 1.4ms preprocess, 134.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 137.4ms
# Speed: 2.0ms preprocess, 137.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 133.8ms
# Speed: 1.3ms preprocess, 133.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 132.3ms
# Speed: 1.2ms preprocess, 132.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 132.3ms
# Speed: 1.2ms preprocess, 132.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 131.1ms
# Speed: 1.3ms preprocess, 131.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 137.4ms
# Speed: 1.8ms preprocess, 137.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 135.1ms
# Speed: 1.4ms preprocess, 135.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 158.9ms
# Speed: 1.0ms preprocess, 158.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 200.3ms
# Speed: 1.6ms preprocess, 200.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 624.8ms
# Speed: 17.6ms preprocess, 624.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 259.7ms
# Speed: 1.2ms preprocess, 259.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 271.5ms
# Speed: 1.4ms preprocess, 271.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 240.0ms
# Speed: 4.4ms preprocess, 240.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 206.9ms
# Speed: 1.7ms preprocess, 206.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 147.6ms
# Speed: 1.5ms preprocess, 147.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 176.4ms
# Speed: 1.9ms preprocess, 176.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 278.1ms
# Speed: 1.5ms preprocess, 278.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 317.5ms
# Speed: 1.5ms preprocess, 317.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 274.8ms
# Speed: 2.0ms preprocess, 274.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 311.4ms
# Speed: 1.2ms preprocess, 311.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 241.9ms
# Speed: 2.1ms preprocess, 241.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 591.4ms
# Speed: 5.2ms preprocess, 591.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 249.7ms
# Speed: 1.4ms preprocess, 249.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 229.8ms
# Speed: 1.6ms preprocess, 229.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 4 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 224.4ms
# Speed: 3.0ms preprocess, 224.4ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 325.6ms
# Speed: 1.7ms preprocess, 325.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 342.6ms
# Speed: 7.5ms preprocess, 342.6ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 394.6ms
# Speed: 2.5ms preprocess, 394.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 222.6ms
# Speed: 1.5ms preprocess, 222.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 181.4ms
# Speed: 1.7ms preprocess, 181.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 194.2ms
# Speed: 1.8ms preprocess, 194.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 238.5ms
# Speed: 1.9ms preprocess, 238.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 147.1ms
# Speed: 1.8ms preprocess, 147.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 142.5ms
# Speed: 1.4ms preprocess, 142.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 143.1ms
# Speed: 2.1ms preprocess, 143.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 1 white-rook, 184.6ms
# Speed: 1.5ms preprocess, 184.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 204.1ms
# Speed: 1.5ms preprocess, 204.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 163.9ms
# Speed: 1.6ms preprocess, 163.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 223.8ms
# Speed: 1.6ms preprocess, 223.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 147.1ms
# Speed: 1.1ms preprocess, 147.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 152.8ms
# Speed: 1.2ms preprocess, 152.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 146.5ms
# Speed: 1.8ms preprocess, 146.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 135.8ms
# Speed: 1.1ms preprocess, 135.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 146.0ms
# Speed: 1.1ms preprocess, 146.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 136.5ms
# Speed: 1.2ms preprocess, 136.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 140.4ms
# Speed: 1.2ms preprocess, 140.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 135.8ms
# Speed: 1.1ms preprocess, 135.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 172.5ms
# Speed: 1.3ms preprocess, 172.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 195.2ms
# Speed: 2.6ms preprocess, 195.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 142.6ms
# Speed: 1.3ms preprocess, 142.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 138.0ms
# Speed: 1.2ms preprocess, 138.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 134.0ms
# Speed: 1.6ms preprocess, 134.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 137.3ms
# Speed: 1.5ms preprocess, 137.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 141.4ms
# Speed: 1.2ms preprocess, 141.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 137.4ms
# Speed: 1.1ms preprocess, 137.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 136.1ms
# Speed: 1.3ms preprocess, 136.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 131.2ms
# Speed: 1.3ms preprocess, 131.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 127.1ms
# Speed: 1.3ms preprocess, 127.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 132.5ms
# Speed: 1.8ms preprocess, 132.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 132.1ms
# Speed: 1.0ms preprocess, 132.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 127.9ms
# Speed: 1.1ms preprocess, 127.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 134.9ms
# Speed: 1.2ms preprocess, 134.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 142.1ms
# Speed: 1.2ms preprocess, 142.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 142.9ms
# Speed: 1.1ms preprocess, 142.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 133.4ms
# Speed: 1.2ms preprocess, 133.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 130.0ms
# Speed: 1.2ms preprocess, 130.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 145.1ms
# Speed: 1.1ms preprocess, 145.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 140.4ms
# Speed: 1.4ms preprocess, 140.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 2 black-kings, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 139.0ms
# Speed: 2.5ms preprocess, 139.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 133.9ms
# Speed: 1.6ms preprocess, 133.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 128.6ms
# Speed: 1.1ms preprocess, 128.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 132.6ms
# Speed: 1.0ms preprocess, 132.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 156.1ms
# Speed: 1.4ms preprocess, 156.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 176.0ms
# Speed: 1.7ms preprocess, 176.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 177.8ms
# Speed: 1.0ms preprocess, 177.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 136.4ms
# Speed: 1.8ms preprocess, 136.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 126.2ms
# Speed: 1.1ms preprocess, 126.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
# [' . . q k b n N\n. p p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . q k b n N\np b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . q k b n N\np b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . q k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . . .\nR . P . . K P P\nR . . Q . B . ', ' . . q k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . .\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ']
# [['', '.', '.', 'q', 'k', 'b', 'n', 'N'], ['.', 'b', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', '.', '.', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', '.'], ['.', '.', 'N', '.', '.', '.', '.', '.'], ['P', '.', 'P', '.', '.', 'K', 'P', 'P'], ['R', '.', '.', 'Q', '.', 'B', '.', '']]
#
#
# [' . . . k b n N\n. . p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np p p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. . p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np b p b . . p .\n. . . p . . . .\nn . . R p . . .\n. P . . P . . q\n. . N . . . . .\nR . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nR . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nR . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. . p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np b p b . . q .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nR . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np . p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np . p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np . p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np b p b . . . .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . . .\nP . P . . K P P\nR . . Q . B . ', ' . . . k b n N\np b p b . . . .\n. . . p . . . .\nn .  ...
# [['', '.', '.', '.', 'k', 'b', 'n', 'N'], ['.', 'b', 'p', 'b', '.', '.', '.', '.'], ['.', '.', '.', 'p', '.', '.', '.', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', 'q'], ['.', '.', 'N', '.', '.', '.', '.', '.'], ['P', '.', 'P', '.', '.', 'K', 'P', 'P'], ['R', '.', '.', 'Q', '.', 'B', '.', '']]
#
#
# [' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. . p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. . p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . . .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. p p b . . p .\n. . . b . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. . p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . k\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nR . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nR . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nR . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. . p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nR . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nR . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\n. b p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nP . P . . K . P\nR . . Q . B . ', ' . . . k b n N\np p p b . . p .\n. . . p . . . .\nn . . P p . . .\n. P . . P . . q\n. . N . . . P .\nR . P . . K . P\nR . . Q . B . ']
# [['', '.', '.', '.', 'k', 'b', 'n', 'N'], ['.', 'b', 'p', 'b', '.', '.', 'p', '.'], ['.', '.', '.', 'p', '.', '.', '.', '.'], ['n', '.', '.', 'P', 'p', '.', '.', '.'], ['.', 'P', '.', '.', 'P', '.', '.', 'q'], ['.', '.', 'N', '.', '.', '.', 'P', '.'], ['P', '.', 'P', '.', '.', 'K', '.', 'P'], ['R', '.', '.', 'Q', '.', 'B', '.', '']]
#
#
# getting k from gen_pgn
# I0000 00:00:1733859685.461090  787626 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 83.1), renderer: Apple M1
# W0000 00:00:1733859685.469069 1019216 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733859685.473740 1019215 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Closest pair: (220.74419584668584, [(37, 1317), (51, 1317), (51, 1334), (37, 1334)], [(113, 1392), (133, 1393), (132, 1414), (112, 1413)])
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 153.1ms
# Speed: 1.3ms preprocess, 153.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 127.0ms
# Speed: 5.5ms preprocess, 127.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 132.0ms
# Speed: 1.8ms preprocess, 132.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 134.2ms
# Speed: 1.3ms preprocess, 134.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 178.7ms
# Speed: 1.3ms preprocess, 178.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 135.8ms
# Speed: 1.1ms preprocess, 135.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 126.9ms
# Speed: 1.3ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 121.7ms
# Speed: 1.0ms preprocess, 121.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 124.1ms
# Speed: 1.6ms preprocess, 124.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 6 white-pawns, 1 white-queen, 4 white-rooks, 132.3ms
# Speed: 1.1ms preprocess, 132.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 134.5ms
# Speed: 1.2ms preprocess, 134.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 6 white-pawns, 1 white-queen, 4 white-rooks, 128.9ms
# Speed: 1.2ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 6 white-pawns, 1 white-queen, 4 white-rooks, 128.6ms
# Speed: 1.3ms preprocess, 128.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 134.2ms
# Speed: 1.1ms preprocess, 134.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 127.4ms
# Speed: 1.2ms preprocess, 127.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 133.1ms
# Speed: 1.8ms preprocess, 133.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 127.5ms
# Speed: 1.1ms preprocess, 127.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 142.2ms
# Speed: 1.7ms preprocess, 142.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 6 white-pawns, 1 white-queen, 4 white-rooks, 131.7ms
# Speed: 1.3ms preprocess, 131.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 129.0ms
# Speed: 1.4ms preprocess, 129.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 128.4ms
# Speed: 2.0ms preprocess, 128.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 6 white-pawns, 1 white-queen, 4 white-rooks, 128.4ms
# Speed: 1.2ms preprocess, 128.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 127.0ms
# Speed: 1.0ms preprocess, 127.0ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 127.6ms
# Speed: 1.5ms preprocess, 127.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 128.5ms
# Speed: 1.1ms preprocess, 128.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 139.6ms
# Speed: 1.2ms preprocess, 139.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 6 white-pawns, 1 white-queen, 3 white-rooks, 130.7ms
# Speed: 1.6ms preprocess, 130.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 152.5ms
# Speed: 1.0ms preprocess, 152.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 167.6ms
# Speed: 1.1ms preprocess, 167.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 135.5ms
# Speed: 1.1ms preprocess, 135.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 137.3ms
# Speed: 1.2ms preprocess, 137.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 129.5ms
# Speed: 1.2ms preprocess, 129.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 1 black-king, 2 black-knights, 5 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 2 white-rooks, 201.1ms
# Speed: 3.6ms preprocess, 201.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 2 black-kings, 2 black-knights, 5 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 170.4ms
# Speed: 1.7ms preprocess, 170.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 3 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 126.9ms
# Speed: 1.6ms preprocess, 126.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 130.0ms
# Speed: 1.1ms preprocess, 130.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 3 white-rooks, 150.6ms
# Speed: 1.0ms preprocess, 150.6ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 130.6ms
# Speed: 1.1ms preprocess, 130.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 2 black-bishops, 2 black-kings, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 2 white-knights, 7 white-pawns, 1 white-queen, 4 white-rooks, 134.6ms
# Speed: 1.1ms preprocess, 134.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 416)
#
# ...
# [['', '.', 'r', 'k', '.', '.', '.', 'q'], ['Q', '.', '.', '.', 'n', '.', '.', '.'], ['.', '.', '.', 'p', '.', '.', 'p', 'b'], ['P', '.', '.', 'p', 'p', '.', '.', '.'], ['.', 'p', 'P', '.', 'P', '.', '.', 'P'], ['.', '.', '.', 'B', '.', '.', 'P', '.'], ['R', 'R', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'K', 'R', '.', '']]
#
#
# [' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p k\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p k\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p k\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p k\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p k\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p k\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP . . b p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . n . . .\n. . . p . . p b\nP .  ...
# [['', '.', 'r', 'k', '.', '.', '.', 'q'], ['Q', '.', '.', '.', 'n', '.', '.', '.'], ['.', '.', '.', 'p', '.', '.', 'p', 'b'], ['P', '.', '.', '.', 'p', '.', '.', '.'], ['.', 'R', 'P', '.', 'P', '.', '.', 'P'], ['.', '.', '.', 'B', '.', '.', 'P', '.'], ['R', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'K', 'R', '.', '']]
#
#
# [' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . . r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . p r . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . p r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . p r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\nQ . . . . . . .\n. . n p . . p b\nP .  ...
# [['', '.', 'r', 'k', '.', '.', '.', 'q'], ['Q', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', 'n', 'p', '.', '.', 'p', 'b'], ['P', '.', '.', 'q', 'p', '.', '.', '.'], ['.', 'R', 'P', '.', 'P', '.', '.', 'P'], ['.', '.', '.', 'B', '.', '.', 'P', '.'], ['R', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'K', 'R', '.', '']]
#
#
# [' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . . r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . p r . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . . p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p k\nP . . q r . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . p p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nP . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP . . q p . . .\n. R P . P . . P\n. . . B . . P .\nR . . . . . . .\n. . . . K R . ', ' . r k . . . q\n. . . . . . . .\n. Q n p . . p b\nP .  ...
# [['', '.', 'r', 'k', '.', '.', '.', 'q'], ['.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'Q', 'n', 'p', '.', '.', 'p', 'b'], ['P', '.', '.', 'q', 'p', '.', '.', '.'], ['.', 'R', 'P', '.', 'P', '.', '.', 'P'], ['.', '.', '.', 'B', '.', '.', 'P', '.'], ['R', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', 'K', 'R', '.', '']]
#
#
# ['1. .. h4 2. g3 .. ', '1. .. Qh4 2. g3 .. ', '1. .. f4 2. Ng6 fxg3 3. .. No valid move found 4. Nxh8 .. ', '1. .. Bxb5 2. Rxa2 b6 3. cxa2 Ne7 4. Rb2 .. ', '1. Ke6 Kxa2 2. Qf7 c6 3. .. No valid move found 4. .. cxa2 5. .. No valid move found 6. .. No valid move found 7. .. No valid move found 8. .. Rxd5 9. Rxb4 Nd5 10. Qb6 .. ']

# %%
import pandas as pd

# %%
# vids = ['2_Move_rotate_student.mp4','2_move_student.mp4','4_Move_studet.mp4','6_Move_student.mp4','8_Move_student.mp4', '(Bonus)Long_video_student.mp4']
vids = ['kaggle/input/2_Move_rotate_student.mp4','kaggle/input/2_move_student.mp4','kaggle/input/4_Move_studet.mp4','kaggle/input/6_Move_student.mp4','kaggle/input/8_Move_student.mp4', 'kaggle/input/(Bonus)Long_video_student.mp4']
# pgn.append('1.')
df = pd.DataFrame({
    "row_id": vids,
    "output": pgn[:6]
})

# Save to CSV
df.to_csv("kaggle/working/submission.csv", index=False, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       2 vids = ['kaggle/input/2_Move_rotate_student.mp4','kaggle/input/2_move_student.mp4','kaggle/input/4_Move_studet.mp4','kaggle/input/6_Move_student.mp4','kaggle/input/8_Move_student.mp4', 'kaggle/input/(Bonus)Long_video_student.mp4']
#       3 # pgn.append('1.')
# ----> 4 df = pd.DataFrame({
#       5     "row_id": vids,
#       6     "output": pgn[:6]
#       7 })
#       9 # Save to CSV
#      10 df.to_csv("kaggle/working/submission.csv", index=False, encoding="utf-8")
#
# File ~/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/code/work/RoboticsAI/chess-detection/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length
